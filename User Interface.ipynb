# %%
quiz = { "What’s the hottest planet in the solar system☀️? " : "venus",
        "'The capital of Croatia is Dubrovnik 🇸🇮', True or False? " : "false",
        "How many hearts does an octopus have🐙? " : "3", 
        "What German city is famous for its annual Oktoberfest celebration🍺? ": "munich",
        "What is the closest living relative to a T-Rex🐔? " : "chicken", 
        "What year was the IT company Service Titan founded🧠? " : "2007",
        "'I have cities, but no houses. I have mountains, but no trees. I have water, but no fish. What am I 🤔?' " : "map",  
        "Which school in Yerevan was named after Galust Gylbenyan🏫 ? " : "190",
        "What has to be broken before you can use it 👀? " : "egg",
        "Who is the best professor in AUA 👩‍🏫? " : "liana harutyunyan"}

mistake_count = 0
name = input("Enter your name: ")
q = input("Do you want to be a 🤑BILLIONAIRE💰 (yes/no)?  ").lower()

win = True

while True:
    if q != "yes" and q != "no":
        print("Invalid input: yes/no ? ")
        q = input("Do you want to be a 🤑BILLIONAIRE💰 (yes/no)? ").lower() 
        continue
    elif q == "no":
        print()
        print("\033[94mCOME BACK WITH BIGGER AMNBITIONS NEXT TIME!\033[0m")
        break
    elif q == "yes":
        print()
        print("\033[95mBe attentive! You can only make 2 mistakes. GOOD LUCK!🤩 \033[0m ")
        print()
        for i in quiz.keys():
            q = input(i).lower()
            if q == quiz[i]:
                print("\033[92mTHAT'S CORRECT!🤓\033[0m")
                print()
            elif q != quiz[i]:
                if mistake_count < 2:
                    print("\033[91mTHAT'S INCORRECT!😱 \033[0m")
                    mistake_count += 1
                    print(f"\033[91mMistake count :  {mistake_count}\033[0m")
                    print()
                else: 
                    print(f"Unfortunately, You've made {mistake_count +1} mistakes 💔. Therefore, You lost...")
                    print("Better luck next time! ✊")
                    win = False
                    break
                        
        break
    break
    
    
print()

if win == True:
    print(f"\033[91m🥳🥳 CONGRATULATIONS {name.upper()} 👏👏👏\033[0m")  
    p = input("")
    print("\033[93mYOU JUST BECAME🤩🤩\033[0m")
    p = input("")
    print("\033[92m💸 A BILLIONAIRE! 💸 \033[0m") 
    p = input("")
    print("\033[94mBUT THAT'S NOT ALL 😈\033[0m")
    p = input("")
    print("\033[96mTHERE'S MORE! 💵\033[0m") 
    p = input("")
    p = input("\033[95mARE YOU READY TO PREDICT YOUR FUTURE? (yes/no)\033[0m").lower()
# Out:
# Enter your name: h
# Do you want to be a 🤑BILLIONAIRE💰 (yes/no)?  yes
#
# Be attentive! You can only make 2 mistakes. GOOD LUCK!🤩
#
# What’s the hottest planet in the solar system☀️? venus
# THAT'S CORRECT!🤓
#
# 'The capital of Croatia is Dubrovnik 🇸🇮', True or False? false
# THAT'S CORRECT!🤓
#
# How many hearts does an octopus have🐙? 3
# THAT'S CORRECT!🤓
#
# What German city is famous for its annual Oktoberfest celebration🍺? m
# THAT'S INCORRECT!😱
# Mistake count :  1
#
# What is the closest living relative to a T-Rex🐔? chicken
# THAT'S CORRECT!🤓
#
# What year was the IT company Service Titan founded🧠? 2007
# THAT'S CORRECT!🤓
#
# 'I have cities, but no houses. I have mountains, but no trees. I have water, but no fish. What am I 🤔?' map
# THAT'S CORRECT!🤓
#
# Which school in Yerevan was named after Galust Gylbenyan🏫 ? 190
# THAT'S CORRECT!🤓
#
# What has to be broken before you can use it 👀? egg
# THAT'S CORRECT!🤓
#
# Who is the best professor in AUA 👩‍🏫? liana
# THAT'S INCORRECT!😱
# Mistake count :  2
#
#
# 🥳🥳 CONGRATULATIONS H 👏👏👏
#
# YOU JUST BECAME🤩🤩
#
# 💸 A BILLIONAIRE! 💸
#
# BUT THAT'S NOT ALL 😈
#
# THERE'S MORE! 💵
#
# Are you ready to predict your future? (yes/no)j

# %%
#quiz = { "What’s the hottest planet in the solar system☀️? " : "venus",
        "'The capital of Croatia is Dubrovnik 🇸🇮', True or False? " : "false",
        "How many hearts does an octopus have🐙? " : "three", #or 3
        "What German city is famous for its annual Oktoberfest celebration🍺? ": "munich", #or munchen
        "What is the closest living relative to a T-Rex🐔? " : "chicken", 
        "What year was the IT company Service Titan founded🧠? " : "2007",
        "'I have cities, but no houses. I have mountains, but no trees. I have water, but no fish. What am I 🤔?' " : "map",  
        "Which school in Yerevan was named after Galust Gylbenyan🏫 ? " : "190",
        "What has to be broken before you can use it 👀? " : "egg",
        "Who is the best professor in AUA 👩‍🏫? " : "Liana Harutyunyan"}
            
            #👏🥳🧾 💶 💵 🪙 💳 💸 💴
