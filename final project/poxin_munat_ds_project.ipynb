# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("df_ready.csv")
df
# Out:
#       position  wealth               industry                 full_name  age  \
# 0            1  211000       Fashion & Retail  Bernard Arnault & family   74
# 1            2  180000             Automotive                 Elon Musk   51
# 2            3  114000             Technology                Jeff Bezos   59
# 3            4  107000             Technology             Larry Ellison   78
# 4            5  106000  Finance & Investments            Warren Buffett   92
# ...        ...     ...                    ...                       ...  ...
# 2586      2540    1000             Healthcare                   Yu Rong   51
# 2587      2540    1000        Food & Beverage    Richard Yuengling, Jr.   80
# 2588      2540    1000          Manufacturing             Zhang Gongyun   60
# 2589      2540    1000            Real Estate    Zhang Guiping & family   71
# 2590      2540    1000            Diversified               Inigo Zobel   66
#
# ...

# %% [markdown]
# ## Data cleaning

# %%
df.shape
# Out:
# (2591, 30)

# %%
df["position"].nunique()
# Out:
# 219

# %%
to_drop_cols = ["country_lat", "country_long", "position"]
df = df.drop(to_drop_cols, axis = 1) #explain why later

# %%
df
# Out:
#       wealth               industry                 full_name  age  \
# 0     211000       Fashion & Retail  Bernard Arnault & family   74
# 1     180000             Automotive                 Elon Musk   51
# 2     114000             Technology                Jeff Bezos   59
# 3     107000             Technology             Larry Ellison   78
# 4     106000  Finance & Investments            Warren Buffett   92
# ...      ...                    ...                       ...  ...
# 2586    1000             Healthcare                   Yu Rong   51
# 2587    1000        Food & Beverage    Richard Yuengling, Jr.   80
# 2588    1000          Manufacturing             Zhang Gongyun   60
# 2589    1000            Real Estate    Zhang Guiping & family   71
# 2590    1000            Diversified               Inigo Zobel   66
#
#      country_of_residence city_of_residence                        source  \
# 0                  France             Paris                          LVMH
# ...

# %%
df.info() #it does not have null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2591 entries, 0 to 2590
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   wealth                2591 non-null   int64
#  1   industry              2591 non-null   object
#  2   full_name             2591 non-null   object
#  3   age                   2591 non-null   int64
#  4   country_of_residence  2591 non-null   object
#  5   city_of_residence     2591 non-null   object
#  6   source                2591 non-null   object
#  7   citizenship           2591 non-null   object
#  8   gender                2591 non-null   object
#  9   birth_date            2591 non-null   object
#  10  last_name             2591 non-null   object
#  11  first_name            2591 non-null   object
#  12  residence_state       2591 non-null   object
#  13  residence_region      2591 non-null   object
#  14  birth_year            2591 non-null   int64
# ...

# %%
duplicate_rows = df.duplicated().nunique() #no duplicates
missing_values = df.isnull().sum().sum()

# %%
print(f"there are {duplicate_rows} duplicate rows and {missing_values} missing values")
# Out:
# there are 1 duplicate rows and 0 missing values

# %%
df["g_primary_ed_enroll"] #consider this later. Ask for Liana's opinion
# Out:
# 0       102.5
# 1       101.8
# 2       101.8
# 3       101.8
# 4       101.8
#         ...
# 2586    100.2
# 2587    101.8
# 2588    100.2
# 2589    100.2
# 2590    107.5
# Name: g_primary_ed_enroll, Length: 2591, dtype: float64

# %%
min_primary = np.min(df["g_primary_ed_enroll"])
min_primary
max_primary = np.max(df["g_primary_ed_enroll"])
max_primary
# Out:
# 142.1

# %%
df["g_primary_ed_enroll"].describe()
# Out:
# count    2591.000000
# mean      100.232420
# std        11.966391
# min         0.000000
# 25%       100.200000
# 50%       101.800000
# 75%       102.600000
# max       142.100000
# Name: g_primary_ed_enroll, dtype: float64

# %%
df.describe()
# Out:
#               wealth          age   birth_year  birth_month    birth_day  \
# count    2591.000000  2591.000000  2591.000000  2591.000000  2591.000000
# mean     4666.190660    65.252798  1957.133925     5.646083    11.882671
# std      9917.104258    13.055442    13.074254     3.732279     9.941884
# min      1000.000000    18.000000  1921.000000     1.000000     1.000000
# 25%      1500.000000    56.000000  1948.000000     2.000000     1.000000
# 50%      2400.000000    65.000000  1957.000000     5.000000    10.000000
# 75%      4300.000000    75.000000  1966.000000     9.000000    21.000000
# max    211000.000000   101.000000  2004.000000    12.000000    31.000000
#
#         gdp_country  g_tertiary_ed_enroll  g_primary_ed_enroll  \
# count  2.591000e+03           2591.000000          2591.000000
# mean   1.102966e+13             64.125743           100.232420
# std    9.641891e+12             24.527813            11.966391
# ...

# %%
df["wealth(bln)"] = df["wealth"]/1000
# Out:
#                    industry                 full_name  age  \
# 0          Fashion & Retail  Bernard Arnault & family   74
# 1                Automotive                 Elon Musk   51
# 2                Technology                Jeff Bezos   59
# 3                Technology             Larry Ellison   78
# 4     Finance & Investments            Warren Buffett   92
# ...                     ...                       ...  ...
# 2586             Healthcare                   Yu Rong   51
# 2587        Food & Beverage    Richard Yuengling, Jr.   80
# 2588          Manufacturing             Zhang Gongyun   60
# 2589            Real Estate    Zhang Guiping & family   71
# 2590            Diversified               Inigo Zobel   66
#
#      country_of_residence city_of_residence                        source  \
# 0                  France             Paris                          LVMH
# 1           United States            Austin                 Tesla, SpaceX
# ...

# %%
df.drop("wealth", axis = 1, inplace = True)
df
# Out:
#                    industry                 full_name  age  \
# 0          Fashion & Retail  Bernard Arnault & family   74
# 1                Automotive                 Elon Musk   51
# 2                Technology                Jeff Bezos   59
# 3                Technology             Larry Ellison   78
# 4     Finance & Investments            Warren Buffett   92
# ...                     ...                       ...  ...
# 2586             Healthcare                   Yu Rong   51
# 2587        Food & Beverage    Richard Yuengling, Jr.   80
# 2588          Manufacturing             Zhang Gongyun   60
# 2589            Real Estate    Zhang Guiping & family   71
# 2590            Diversified               Inigo Zobel   66
#
#      country_of_residence city_of_residence                        source  \
# 0                  France             Paris                          LVMH
# 1           United States            Austin                 Tesla, SpaceX
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.columns = np.array(list("wealth(bln)") + df.columns[1:])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:190, in OpsMixin.__radd__(self, other)
#     188 @unpack_zerodim_and_defer("__radd__")
#     189 def __radd__(self, other):
# --> 190     return self._arith_method(other, roperator.radd)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:7158, in Index._arith_method(self, other, op)
#    7148 if (
# ...

# %% [markdown]
# ### Ideas for plotting

# %% [markdown]
# 1.) Scatter plot connecting the age(calculated in a way that it's continuos) and wealth

# %% [markdown]
# 2.) Scatter plot relating the wealth/revenue with the tax rate

# %% [markdown]
# 3.) Here CPI can have two meanings Corruption Perceptions Index or Consumer price indexes. I think it is the latter, can be correlated with the wealth again or with the tax rate.

# %% [markdown]
# 4.) Wealth, tax rates, gdp by continents/countries. Plotted as a bar plot

# %% [markdown]
# 5.) Find whether anyone is armenian

# %% [markdown]
# 6.) the frequencies of the birthdays/birth months

# %% [markdown]
# 7.) male/female comparison in a bar plot

# %% [markdown]
# 8.) age distribution

# %% [markdown]
# 9.)

# %%
df.shape
# Out:
# (2591, 30)
